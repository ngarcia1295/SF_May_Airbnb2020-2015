# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf

# %%
listings = pd.read_csv('may_master_list2.csv')

# %%
calendar = pd.read_csv('may_master_cal_edited.csv')

# %%
calendar.head()
# Out:
#    Unnamed: 0  listing_id        date available   price  year
# 0           0       74758  2020-05-06         t  $35.00  2020
# 1           1       74758  2020-05-07         t  $35.00  2020
# 2           2       74758  2020-05-08         t  $35.00  2020
# 3           3       74758  2020-05-09         t  $35.00  2020
# 4           4       74758  2020-05-10         t  $35.00  2020

# %%
listings.head()
# Out:
#    Unnamed: 0    id       scrape_id last_scraped  \
# 0           0   958  20200506054328   2020-05-06
# 1           1  5858  20200506054328   2020-05-06
# 2           2  7918  20200506054328   2020-05-06
# 3           3  8142  20200506054328   2020-05-06
# 4           4  8339  20200506054328   2020-05-06
#
#                                          description  host_id  \
# 0  New update: the house next door is under const...     1169
# 1  We live in a large Victorian house on a quiet ...     8904
# 2  Nice and good public transportation.  7 minute...    21994
# 3  Nice and good public transportation.  7 minute...    21994
# 4  Pls email before booking.  Interior featured i...    24215
#
#    host_total_listings_count                            street  \
# 0                        1.0  San Francisco, CA, United States
# 1                        2.0  San Francisco, CA, United States
# 2                       10.0  San Francisco, CA, United States
# ...

# %%
listings.columns
# Out:
# Index(['Unnamed: 0', 'id', 'scrape_id', 'last_scraped', 'description',
#        'host_id', 'host_total_listings_count', 'street', 'neighbourhood',
#        'city', 'state', 'zipcode', 'country_code', 'country', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bedrooms', 'beds', 'square_feet', 'price', 'has_availability',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'calculated_host_listings_count', 'year'],
#       dtype='object')

# %%
listings['price'] = listings['price'].str.replace('$', '')
listings['price'] = listings['price'].str.replace(',', '')

# %%
from sklearn.model_selection import train_test_split

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42486 entries, 0 to 42485
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      42486 non-null  int64
#  1   id                              42486 non-null  int64
#  2   scrape_id                       42486 non-null  int64
#  3   last_scraped                    42486 non-null  object
#  4   description                     42387 non-null  object
#  5   host_id                         42486 non-null  int64
#  6   host_total_listings_count       37006 non-null  float64
#  7   street                          42486 non-null  object
#  8   neighbourhood                   40491 non-null  object
#  9   city                            42475 non-null  object
#  10  state                           42468 non-null  object
#  11  zipcode                         42041 non-null  object
# ...

# %%
listings['price'] = listings.price.astype(float)

# %%
zipcode = listings['zipcode']

# %%
zipcode.value_counts()
# Out:
# 94110     1859
# 94117     1282
# 94114     1243
# 94109     1142
# 94102     1001
#           ...
#              2
# 941290       1
# 94130        1
# 94129        1
# 941580       1
# Name: zipcode, Length: 72, dtype: int64

# %%
listings['zipcode'] = listings['zipcode'].str.replace('CA', '')

# %%
listings['zipcode'] = listings['zipcode'].str.replace('.', '')

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42486 entries, 0 to 42485
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      42486 non-null  int64
#  1   id                              42486 non-null  int64
#  2   scrape_id                       42486 non-null  int64
#  3   last_scraped                    42486 non-null  object
#  4   description                     42387 non-null  object
#  5   host_id                         42486 non-null  int64
#  6   host_total_listings_count       37006 non-null  float64
#  7   street                          42486 non-null  object
#  8   neighbourhood                   40491 non-null  object
#  9   city                            42475 non-null  object
#  10  state                           42468 non-null  object
#  11  zipcode                         42486 non-null  int64
# ...

# %%
listings.zipcode.value_counts()
# Out:
# 150.0     1596
# 200.0     1332
# 100.0     1280
# 250.0     1252
# 125.0     1003
#           ...
# 947.0        1
# 1895.0       1
# 1900.0       1
# 1675.0       1
# 24.0         1
# Name: zipcode, Length: 700, dtype: int64

# %%
listings.dropna(inplace=True)

# %%
listings.year.astype(float)
# Out:
# 0        2020.0
# 1        2020.0
# 2        2020.0
# 3        2020.0
# 4        2020.0
#           ...
# 42481    2015.0
# 42482    2015.0
# 42483    2015.0
# 42484    2015.0
# 42485    2015.0
# Name: year, Length: 42486, dtype: float64

# %%
li

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42486 entries, 0 to 42485
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      42486 non-null  int64
#  1   id                              42486 non-null  int64
#  2   scrape_id                       42486 non-null  int64
#  3   last_scraped                    42486 non-null  object
#  4   description                     42387 non-null  object
#  5   host_id                         42486 non-null  int64
#  6   host_total_listings_count       37006 non-null  float64
#  7   street                          42486 non-null  object
#  8   neighbourhood                   40491 non-null  object
#  9   city                            42475 non-null  object
#  10  state                           42468 non-null  object
#  11  zipcode                         42041 non-null  object
# ...

# %%
newdf = calendar.groupby(['year', 'available'])

# %%
calendar.groupby('year')

# %%
cal = calendar[['year', 'available']]

# %%
cal_total = cal.groupby('year')['available'].count()

# %%
cal_total['year', 'available'] = cal.groupby('year')['available'].count().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#    1053         try:
# -> 1054             self.index._engine.set_value(values, key, value)
#    1055             return
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: ('year', 'available')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
# ...

# %%
df1 = pd.DataFrame(data=cal, columns=['year'])
df2 = pd.DataFrame(data=cal_total, columns=['available'])
df = pd.merge(df1, df2, left_index=True, right_index=True)

# %%
df
# Out:
#       year  available
# 2015  2020    1979395
# 2016  2020    2951390
# 2017  2020    3201780
# 2018  2020    1742145
# 2019  2020    2683845
# 2020  2020    2948470

# %%
cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15507025 entries, 0 to 15507024
# Data columns (total 2 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   year       int64
#  1   available  object
# dtypes: int64(1), object(1)
# memory usage: 236.6+ MB

# %%
listings.dropna(axis=1, thresh=n)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-082549687880> in <module>
# ----> 1 listings.dropna(axis=1, thresh=n)
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42486 entries, 0 to 42485
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      42486 non-null  int64
#  1   id                              42486 non-null  int64
#  2   scrape_id                       42486 non-null  int64
#  3   last_scraped                    42486 non-null  object
#  4   description                     42387 non-null  object
#  5   host_id                         42486 non-null  int64
#  6   host_total_listings_count       37006 non-null  float64
#  7   street                          42486 non-null  object
#  8   neighbourhood                   40491 non-null  object
#  9   city                            42475 non-null  object
#  10  state                           42468 non-null  object
#  11  zipcode                         16133 non-null  object
# ...

# %%
listings.bedrooms.value_counts()
# Out:
# 1.0     9694
# 2.0     2848
# 0.0     1729
# 3.0     1365
# 4.0      394
# 5.0       64
# 6.0       24
# 7.0        5
# 14.0       2
# 9.0        1
# 8.0        1
# Name: bedrooms, dtype: int64

# %%
listings.beds.value_counts()
# Out:
# 1.0     8823
# 2.0     4013
# 3.0     1568
# 4.0      838
# 0.0      306
# 5.0      305
# 6.0      111
# 7.0       60
# 8.0       38
# 9.0        7
# 10.0       5
# 14.0       4
# 12.0       2
# 13.0       1
# 16.0       1
# Name: beds, dtype: int64

# %%
listings.accommodates.value_counts()
# Out:
# 2     7322
# 4     3177
# 1     1571
# 3     1297
# 6     1262
# 5      696
# 8      363
# 7      199
# 10      97
# 9       49
# 12      45
# 11      19
# 16      15
# 14      11
# 15      10
# Name: accommodates, dtype: int64

# %%
listings.room_type.value_counts()
# Out:
# Entire home/apt    9607
# Private room       5899
# Shared room         465
# Hotel room          111
# Name: room_type, dtype: int64

# %%
listings.dropna(subset=['room_type'], inplace=True)

# %%
listings.dropna(subset=['beds'], inplace=True)

# %%
listings.dropna(subset=['neighbourhood'], inplace=True)

# %%
dummies = pd.get_dummies(df['neighbourhood'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'neighbourhood'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-338-14f4cb2310e4> in <module>
# ...

# %%
y = listings['price']

# %%
X = listings[['year','neighbourhood','beds', 'room_type']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

# %%
listings_train = pd.concat([X_train, y_train], axis = 1)

# %%
listings_test = pd.concat([X_test,y_test], axis = 1)

# %%
listings_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3217 entries, 6149 to 8358
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           3217 non-null   int64
#  1   neighbourhood  3217 non-null   object
#  2   beds           3217 non-null   float64
#  3   room_type      3217 non-null   object
#  4   price          3217 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 150.8+ KB

# %%
fitted_model = smf.ols(formula='price ~ year + beds + C(neighbourhood) + C(room_type)', data=listings, missing='drop').fit()

# %%
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     27.82
# Date:                Wed, 23 Sep 2020   Prob (F-statistic):          2.52e-288
# Time:                        09:29:11   Log-Likelihood:            -1.1956e+05
# No. Observations:               16081   AIC:                         2.392e+05
# Df Residuals:                   16021   BIC:                         2.397e+05
# Df Model:                          59
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %%
from sklearn.metrics import r2_score

# %%
y_test_pred = fitted_model.predict(X_test)

# %%
fitted_model.params
# Out:
# Intercept                                   -21638.111109
# C(neighbourhood)[T.Balboa Terrace]             -59.336904
# C(neighbourhood)[T.Bayview]                    -74.288366
# C(neighbourhood)[T.Bernal Heights]             -46.641729
# C(neighbourhood)[T.Chinatown]                   18.341846
# C(neighbourhood)[T.Civic Center]               246.456154
# C(neighbourhood)[T.Cole Valley]                -17.123345
# C(neighbourhood)[T.Cow Hollow]                  76.665000
# C(neighbourhood)[T.Crocker Amazon]             -95.641535
# C(neighbourhood)[T.Daly City]                 -124.821016
# C(neighbourhood)[T.Diamond Heights]            -27.043493
# C(neighbourhood)[T.Dogpatch]                    72.928920
# C(neighbourhood)[T.Downtown]                    60.166817
# C(neighbourhood)[T.Duboce Triangle]             39.722237
# C(neighbourhood)[T.Excelsior]                  -97.443417
# C(neighbourhood)[T.Financial District]          13.898685
# ...

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.13907236334986328

# %%
listings.head()
# Out:
#    Unnamed: 0    id       scrape_id last_scraped  \
# 0           0   958  20200506054328   2020-05-06
# 1           1  5858  20200506054328   2020-05-06
# 2           2  7918  20200506054328   2020-05-06
# 3           3  8142  20200506054328   2020-05-06
# 4           4  8339  20200506054328   2020-05-06
#
#                                          description  host_id  \
# 0  New update: the house next door is under const...     1169
# 1  We live in a large Victorian house on a quiet ...     8904
# 2  Nice and good public transportation.  7 minute...    21994
# 3  Nice and good public transportation.  7 minute...    21994
# 4  Pls email before booking.  Interior featured i...    24215
#
#    host_total_listings_count                            street  \
# 0                        1.0  San Francisco, CA, United States
# 1                        2.0  San Francisco, CA, United States
# 2                       10.0  San Francisco, CA, United States
# ...

# %%
listings.groupby('neighbourhood')['price'].mean()
# Out:
# neighbourhood
# 10 min walk to Dogpatch, Mission, SOMA. Walking distance to Whole Foods, Anchor Steam Brewery, Plow, Farley's Coffee. \n\nNewly remodeled public library a 10 min walk away.\n\nPotrero Hill is known for its breathtaking downtown views, great, eclectic vibe, an    139.333333
# Alamo Square                                                                                                                                                                                                                                                           281.219048
# Balboa Terrace                                                                                                                                                                                                                                                         169.108333
# ...

# %%
listings.pivot_table(index = 'neighbourhood', values= ['price', 'has_availability'], aggfunc=sum)
# Out:
#                                                         price
# neighbourhood
# 10 min walk to Dogpatch, Mission, SOMA. Walking...      418.0
# Alamo Square                                         118112.0
# Balboa Terrace                                        40586.0
# Bayview                                              151366.0
# Bernal Heights                                       378909.0
# Chinatown                                             80227.0
# Civic Center                                          41238.0
# Cole Valley                                          132468.0
# Cow Hollow                                           126130.0
# Crocker Amazon                                        35700.0
# Daly City                                             13545.0
# Diamond Heights                                       15809.0
# Dogpatch                                              65586.0
# Downtown                                             288135.0
# ...

# %%
listings.groupby('neighbourhood')['has_availability'].value_counts()
# Out:
# neighbourhood          has_availability
# Alamo Square           t                    114
# Balboa Terrace         t                    111
# Bayview                t                    801
# Bernal Heights         t                    988
# Chinatown              t                    151
# Civic Center           t                     58
# Cole Valley            t                    250
# Cow Hollow             t                    166
# Crocker Amazon         t                    168
# Daly City              t                     68
# Diamond Heights        t                     35
# Dogpatch               t                    101
# Downtown               t                    727
# Duboce Triangle        t                    322
# Excelsior              t                    320
# Financial District     t                    396
# Fisherman's Wharf      t                    232
# Forest Hill            t                     29
# Glen Park              t                    184
# ...

# %%
listings.groupby('neighbourhood')['id'].sum()
# Out:
# neighbourhood
# 10 min walk to Dogpatch, Mission, SOMA. Walking distance to Whole Foods, Anchor Steam Brewery, Plow, Farley's Coffee. \n\nNewly remodeled public library a 10 min walk away.\n\nPotrero Hill is known for its breathtaking downtown views, great, eclectic vibe, an        3067080
# Alamo Square                                                                                                                                                                                                                                                            4240081959
# Balboa Terrace                                                                                                                                                                                                                                                          2693303801
# ...

# %%
listings.pivot_table(index = 'neighbourhood', values= ['price', 'id'], aggfunc=
# Out:
#   File "<ipython-input-141-9e0005a4ef0e>", line 1
#     listings.pivot_table(index = 'neighbourhood', values= ['price', 'id'], aggfunc=count
#                                                                                         ^
# SyntaxError: unexpected EOF while parsing
